# %%
# !python main.py --mode sim --track s --seed 77
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# DEFAULT THETA: {'Ld': 8.0, 'Kp': 1.8, 'Ki': 0.2, 'Kd': 0.4, 'v_ref': 14.0, 'delta_max_deg': 28.0}
# J: 12.349003372516396
# {'reached': True, 't': 11.050000000000022, 'mean_cte': 0.5874765808986314, 'offroad_time': 0.0, 'steer_jerk': 4.2113713111523206}
# Saved: best.json

# %%
# !python main.py --mode play --load best.json --track s
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
